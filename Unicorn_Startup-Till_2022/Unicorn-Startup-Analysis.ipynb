# %% [markdown]
# # Unicorn Startup Data 2022

# %% [markdown]
# ### Importing Liberary

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
import numpy as np
import pandas as pd
import matplotlib as mp

# %% [markdown]
# ### Reading Data Set

# %% [markdown]
# ##### Checking the Encoding of Data Set

# %%
pwd
# Out:
# 'F:\\Data Science Materials\\Python_Env\\Unicorn_Startup-Till_2022'

# %%
with open('F:\\Data Science Materials\\Python_Env\\Unicorn_Startup-Till_2022/Unicorn_Data-Set.csv') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='F:\\Data Science Materials\\Python_Env\\Unicorn_Startup-Till_2022/Unicorn_Data-Set.csv' mode='r' encoding='cp1252'>

# %% [markdown]
# ##### Reading Encoded CSV file into DataFrame df

# %%
Data = pd.read_csv(r'F:\\Data Science Materials\\Python_Env\\Unicorn_Startup-Till_2022/Unicorn_Data-Set.csv',encoding = 'cp1252')

# %%
Data.head()
# Out:
#      Company Valuation($B) Date Joined        Country         CityÂ   \
# 0  ByteDance        140.00  04-07-2017          China        Beijing
# 1     SpaceX        127.00  12-01-2012  United States      Hawthorne
# 2      SHEIN        100.00  07-03-2018          China       Shenzhen
# 3     Stripe         95.00   1/23/2014  United States  San Francisco
# 4      Canva         40.00  01-08-2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %% [markdown]
# ## About Data Set

# %%
Company	Valuation($B)	Date Joined	Country	CityÂ	Industry	Investors

# %%
Data.Industry.unique()
# Out:
# array(['Artificial intelligence', 'Other',
#        'E-commerce & direct-to-consumer', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Artificial Intelligence', 'GIC. Apis Partners, Insight Partners',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
# ...

# %%
Data.Country.unique()
# Out:
# array(['China', 'United States', 'Australia', 'United Kingdom', 'Bahamas',
#        'India', 'Indonesia', 'Turkey', 'Germany', 'Hong Kong',
#        'Seychelles', 'Sweden', 'Mexico', 'Estonia', 'Canada',
#        'Netherlands', 'France', 'Israel', 'Finland', 'Colombia',
#        'Belgium', 'Brazil', 'South Korea', 'Denmark', 'Switzerland',
#        'Lithuania', 'Austria', 'Ireland', 'Singapore', 'Vietnam',
#        'United Arab Emirates', 'Argentina', 'Spain', 'Japan',
#        'Luxembourg', 'Nigeria', 'Philippines', 'Croatia', 'Senegal',
#        'Malaysia', 'Bermuda', 'Norway', 'South Africa', 'Ecuador',
#        'Chile', 'Thailand', 'Czech Republic', 'Italy'], dtype=object)

# %%
df.head()
# Out:
#      Company Valuation($B) Date Joined        Country         CityÂ   \
# 0  ByteDance        140.00  04-07-2017          China        Beijing
# 1     SpaceX        127.00  12-01-2012  United States      Hawthorne
# 2      SHEIN        100.00  07-03-2018          China       Shenzhen
# 3     Stripe         95.00   1/23/2014  United States  San Francisco
# 4      Canva         40.00  01-08-2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
#Total Companies by Country
Data.groupby(['Country']).count()
# Out:
#                       Company  Valuation($B)  Date Joined  CityÂ   Industry  \
# Country
# Argentina                   1              1            1       1         1
# Australia                   8              8            8       8         8
# Austria                     2              2            2       2         2
# Bahamas                     1              1            1       1         1
# Belgium                     3              3            3       3         3
# Bermuda                     1              1            1       1         1
# Brazil                     17             17           17      17        17
# Canada                     19             19           19      19        19
# Chile                       2              2            2       2         2
# China                     173            173          173     173       173
# Colombia                    3              3            3       3         3
# ...

# %%
Data.groupby(['Industry']).count()
# Out:
#                                                     Company  Valuation($B)  \
# Industry
# 500 Global, Rakuten Ventures, Golden Gate Ventures        1              1
# Andreessen Horowitz, DST Global, IDG Capital              1              1
# Artificial Intelligence                                  11             11
# Artificial intelligence                                  74             74
# Auto & transportation                                    39             39
# B Capital Group, Monk's Hill Ventures, Dynamic ...        1              1
# Consumer & retail                                        28             28
# Cybersecurity                                            58             58
# Data management & analytics                              45             45
# Dragonfly Captial, Qiming Venture Partners, DST...        1              1
# E-commerce & direct-to-consumer                         103            103
# ...

# %%
# Relationship b/w Industry and Country
Data.groupby(['Industry','Country']).count()
# Out:
#                                                                   Company  \
# Industry                                           Country
# 500 Global, Rakuten Ventures, Golden Gate Ventures Singapore            1
# Andreessen Horowitz, DST Global, IDG Capital       Hong Kong            1
# Artificial Intelligence                            China                4
#                                                    United States        7
# Artificial intelligence                            Bermuda              1
# ...                                                                   ...
# Travel                                             Spain                1
#                                                    Sweden               1
#                                                    United States        1
# Vertex Ventures SE Asia, Global Founders Capita... Singapore            1
# Vision Plus Capital, GSR Ventures, ZhenFund        Singapore            1
#
# ...

# %%
bygroup_CI= Data.groupby(['Country', 'Industry'])

bygroup_CI.head()
# Out:
#          Company Valuation($B) Date Joined        Country         CityÂ   \
# 0      ByteDance        140.00  04-07-2017          China        Beijing
# 1         SpaceX        127.00  12-01-2012  United States      Hawthorne
# 2          SHEIN        100.00  07-03-2018          China       Shenzhen
# 3         Stripe         95.00   1/23/2014  United States  San Francisco
# 4          Canva         40.00  01-08-2018      Australia    Surry Hills
# ...          ...           ...         ...            ...            ...
# 1164    Polarium          1.00  05-03-2022         Sweden          Kista
# 1165         Opn          1.00  05-09-2022          Japan          Tokyo
# 1166  Remarkable          1.00  05-10-2022         Norway           Oslo
# 1167        Habi          1.00  05-11-2022       Colombia         Bogota
# 1172      Vayyar          1.00  06-06-2022         Israel          Yehud
#
#                              Industry  \
# 0             Artificial intelligence
# ...

# %%
type(Data)
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1178 entries, 0 to 1177
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1178 non-null   object
#  1   Valuation($B)  1178 non-null   object
#  2   Date Joined    1178 non-null   object
#  3   Country        1178 non-null   object
#  4   CityÂ          1178 non-null   object
#  5   Industry       1178 non-null   object
#  6   Investors      1160 non-null   object
# dtypes: object(7)
# memory usage: 64.5+ KB

# %%
Data.describe()
# Out:
#        Company Valuation($B) Date Joined        Country         CityÂ   \
# count     1178          1178        1178           1178           1178
# unique    1175           221         689             48            286
# top     Fabric          1.00   7/13/2021  United States  San Francisco
# freq         2           272           9            633            167
#
#        Industry        Investors
# count      1178             1160
# unique       33             1144
# top     Fintech  Sequoia Capital
# freq        237                3

# %% [markdown]
# ### Comapany with More than $100B Valuation

# %%
Data[Data['Valuation($B)']<100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 Data[Data['Valuation($B)']<100]
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
#type(Data['Valuation ($B)'])

# %%
#Data['Valuation ($B)'] = Data['Valuation ($B)'].astype(int)
